# %% [markdown]
# <a href="https://colab.research.google.com/github/anacvelarde-blip/CursoPhytonProinnova/blob/main/Proyecto_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ana Laura Chavez Velarde

# %%
# conectar con drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# ruta de archivo
ruta_archivo = "/content/drive/MyDrive/Phyton Proinnova 2025B/data_af.csv"

df = pd.read_csv(ruta_archivo)
df
# Out:
#      rating    salary  draft_round  age  experience    bmi
# 0        97  37440000            1   36          17  26.72
# 1        97  32740000            1   29           9  25.27
# 2        96  25840000            1   26           7  24.66
# 3        96  37200000            1   32          13  24.11
# 4        96  38200000            1   31          11  25.98
# ..      ...       ...          ...  ...         ...    ...
# 434      95  40920000            1   33          14  24.11
# 435      95  35360000            1   28           9  23.28
# 436      94  10170000            1   22           3  25.49
# 437      94  39340000            1   31           9  25.04
# 438      91  31580000            1   27           7  25.00
#
# [439 rows x 6 columns]

# %%
display(df.corr())
from matplotlib import pyplot as plt
plt.imshow(df.corr(), cmap='Spectral')
plt.yticks(range(len(df.corr().columns)), df.corr().columns)
plt.xticks(range(len(df.corr().columns)), df.corr().columns, rotation=90)
plt.colorbar()
plt.show()
plt.matshow(df.corr())
plt.colorbar()
plt.show()
# Out:
#                rating    salary  draft_round       age  experience       bmi
# rating       1.000000  0.810253     0.008064  0.292463    0.416545  0.077374
# salary       0.810253  1.000000     0.003895  0.442704    0.532051  0.037066
# draft_round  0.008064  0.003895     1.000000 -0.081857   -0.055498  0.047773
# age          0.292463  0.442704    -0.081857  1.000000    0.920067  0.086674
# experience   0.416545  0.532051    -0.055498  0.920067    1.000000  0.071140
# bmi          0.077374  0.037066     0.047773  0.086674    0.071140  1.000000

# %%
df.plot(kind="scatter", x="rating", y= "salary", s=32, alpha=0.3)

# %%
x = df[["rating"]]
y = df["salary"]

display(x)
display(y)

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
# Out:
#      rating
# 0        97
# 1        97
# 2        96
# 3        96
# 4        96
# ..      ...
# 434      95
# 435      95
# 436      94
# 437      94
# 438      91
#
# [439 rows x 1 columns]
# 0      37440000
# 1      32740000
# 2      25840000
# 3      37200000
# 4      38200000
#          ...
# 434    40920000
# 435    35360000
# 436    10170000
# 437    39340000
# 438    31580000
# Name: salary, Length: 439, dtype: int64
